# %% [markdown]
# # Guía 3 — Introducción a LangChain con OpenAI API
# Curso: **IA en el Aula — Nivel Avanzado**
# Profesor: **Luis Daniel Benavides Navarro**
# Fecha: **Octubre 2025**
#
# En esta guía aprenderás los conceptos básicos de **LangChain**, una librería diseñada para construir aplicaciones impulsadas por modelos de lenguaje, integrando la API de OpenAI con flujos más complejos. Exploraremos cómo crear un primer **prompt chain**, administrar memoria y usar herramientas para componer respuestas inteligentes.

# %% [markdown]
# ## 1️⃣ Instalación y configuración inicial
# LangChain se instala como cualquier otra librería de Python. También usaremos `python-dotenv` para gestionar la clave de OpenAI. Ejecute la siguiente celda:

# %%
# %pip install openai langchain python-dotenv langchain-openai
# Out:
# Requirement already satisfied: openai in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (2.8.0)
# Collecting langchain
#   Downloading langchain-1.0.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dotenv in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (1.2.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting langchain-core<2.0.0,>=1.0.4 (from langchain)
#   Downloading langchain_core-1.0.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.4->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.4->langchain)
#   Downloading langsmith-0.4.42-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.4->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (2.5.0)
# Requirement already satisfied: colorama in c:\users\milo\documents\arep-guia\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading langchain-1.0.5-py3-none-any.whl (93 kB)
# Downloading langchain_core-1.0.4-py3-none-any.whl (471 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.2-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.42-py3-none-any.whl (401 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading langchain_openai-1.0.2-py3-none-any.whl (81 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    ---------------------------------------- 879.1/879.1 kB 5.1 MB/s  0:00:00
# Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl (131 kB)
# Downloading ormsgpack-1.12.0-cp313-cp313-win_amd64.whl (112 kB)
# Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl (277 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, tenacity, regex, ormsgpack, orjson, jsonpatch, tiktoken, requests-toolbelt, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
#
#    ----------------------------------------  0/17 [zstandard]
#    -- -------------------------------------  1/17 [xxhash]
#    ---- -----------------------------------  2/17 [tenacity]
#    ---- -----------------------------------  2/17 [tenacity]
#    ---- -----------------------------------  2/17 [tenacity]
#    ---- -----------------------------------  2/17 [tenacity]
#    ---- -----------------------------------  2/17 [tenacity]
#    ------- --------------------------------  3/17 [regex]
#    ------- --------------------------------  3/17 [regex]
#    ------- --------------------------------  3/17 [regex]
#    --------- ------------------------------  4/17 [ormsgpack]
#    ----------- ----------------------------  5/17 [orjson]
#    -------------- -------------------------  6/17 [jsonpatch]
#    -------------- -------------------------  6/17 [jsonpatch]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ---------------- -----------------------  7/17 [tiktoken]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    ------------------ ---------------------  8/17 [requests-toolbelt]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    --------------------- ------------------  9/17 [langsmith]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ----------------------- ---------------- 10/17 [langgraph-sdk]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ------------------------- -------------- 11/17 [langchain-core]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ---------------------------- ----------- 12/17 [langgraph-checkpoint]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    ------------------------------ --------- 13/17 [langchain-openai]
#    -------------------------------- ------- 14/17 [langgraph-prebuilt]
#    -------------------------------- ------- 14/17 [langgraph-prebuilt]
#    -------------------------------- ------- 14/17 [langgraph-prebuilt]
#    -------------------------------- ------- 14/17 [langgraph-prebuilt]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ----------------------------------- ---- 15/17 [langgraph]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ------------------------------------- -- 16/17 [langchain]
#    ---------------------------------------- 17/17 [langchain]
#
# Successfully installed jsonpatch-1.33 langchain-1.0.5 langchain-core-1.0.4 langchain-openai-1.0.2 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.2 langgraph-sdk-0.2.9 langsmith-0.4.42 orjson-3.11.4 ormsgpack-1.12.0 regex-2025.11.3 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.12.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2️⃣ Cargar variables de entorno y cliente OpenAI
# Crea un archivo `.env` con tu clave de API y cárgala para poder usarla dentro de LangChain. Esto evita exponer tu clave en el código fuente.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()  # Cargar archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("No se encontró la clave OPENAI_API_KEY en el archivo .env")

# Crear cliente LangChain con OpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
print("Cliente LangChain con OpenAI inicializado correctamente.")
# Out:
# Cliente LangChain con OpenAI inicializado correctamente.

# %% [markdown]
# ## 3️⃣ Primer ejemplo: Prompt simple con LangChain
# LangChain utiliza **chains** (cadenas de pasos) para procesar información. Comencemos con una cadena simple que envía un mensaje al modelo y obtiene la respuesta.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Initialize the LLM (uses your OpenAI API key from environment)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)

# Create a simple prompt
prompt = ChatPromptTemplate.from_template(
    "Explica en dos frases el concepto de {tema}."
)

# Combine the components using LCEL (LangChain Expression Language)
chain = prompt | llm | StrOutputParser()

# Run it
result = chain.invoke({"tema": "aprendizaje automático"})
print(result)
# Out:
# El aprendizaje automático es una rama de la inteligencia artificial que permite a las computadoras aprender de datos y mejorar su rendimiento en tareas específicas sin ser programadas explícitamente para ello. Utiliza algoritmos que identifican patrones y hacen predicciones o decisiones basadas en la información disponible.

# %% [markdown]
# ### Explicación
# - **ChatPromptTemplate:** define la estructura del mensaje que se envía al modelo.
# - **ChatOpenAI:** la conexión real al modelo.
# - **chain** crea la cadena de componentes usando LCEL (LangChain Expression Language).
# - **StrOutputParser** convierte la salida estructurada del modelo en texto plano.
# - **chain.invoke:** ejecuta la cadena pasando los valores del prompt.
#
# Este patrón permite reutilizar prompts para distintos temas o contextos.

# %% [markdown]
# ## 4️⃣ Ejemplo 2: Encadenar múltiples pasos
# LangChain permite combinar varios pasos en una misma ejecución. En este ejemplo, crearemos dos prompts: uno para definir un tema y otro para generar una aplicación educativa basada en el resultado.

# %%
# 1. Importaciones necesarias
from langchain_core.prompts import PromptTemplate
from langchain.chains import SimpleSequentialChain
from langchain.chains.llm import LLMChain
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

# 2. Cargar la clave desde .env
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# 3. Crear el modelo LLM
llm = ChatOpenAI(model="gpt-3.5-turbo", api_key=api_key)

# 4. Primer paso: obtener una descripción
primer_prompt = PromptTemplate(
    input_variables=["tema"],
    template="Explica brevemente el concepto de {tema}."
)
primer_chain = LLMChain(llm=llm, prompt=primer_prompt)

# 5. Segundo paso: generar aplicación educativa
segundo_prompt = PromptTemplate(
    input_variables=["concepto"],
    template="Propón una aplicación educativa del siguiente concepto: {concepto}."
)
segundo_chain = LLMChain(llm=llm, prompt=segundo_prompt)

# 6. Combinar ambos pasos en una cadena secuencial
chain_secuencial = SimpleSequentialChain(chains=[primer_chain, segundo_chain])

# 7. Ejecutar la cadena completa
resultado = chain_secuencial.run("realidad aumentada")
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 # 1. Importaciones necesarias
#       2 from langchain_core.prompts import PromptTemplate
# ----> 3 from langchain.chains import SimpleSequentialChain
#       4 from langchain.chains.llm import LLMChain
#       5 from langchain_openai import ChatOpenAI
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from operator import itemgetter

# 1) LLM (usa tu OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# 2) Paso 1: explicar brevemente el concepto de {tema}
primer_prompt = ChatPromptTemplate.from_template(
    "Explica brevemente el concepto de {tema}."
)
primer_paso = primer_prompt | llm | to_str
# `primer_paso` produce un string, por ejemplo: "La realidad aumentada es ..."

# 3) Paso 2: proponer una aplicación educativa usando la salida del paso 1 como {concepto}
segundo_prompt = ChatPromptTemplate.from_template(
    "Propón una aplicación educativa del siguiente concepto: {concepto}."
)
segundo_paso = segundo_prompt | llm | to_str

# 4) Encadenar: mapear la entrada {tema} al primer paso, y su salida a {concepto} del segundo
cadena_secuencial = {"concepto": primer_paso} | segundo_paso

# 5) Ejecutar la cadena completa
resultado = cadena_secuencial.invoke({"tema": "realidad aumentada"})
print(resultado)
# Out:
# **Aplicación Educativa: "Exploradores del Conocimiento"**
#
# **Descripción General:**
# "Exploradores del Conocimiento" es una aplicación de realidad aumentada diseñada para estudiantes de educación primaria y secundaria. Su objetivo es enriquecer el aprendizaje en diversas materias, como ciencias, historia, geografía y matemáticas, al permitir a los estudiantes interactuar con contenidos educativos de manera inmersiva y divertida.
#
# **Funcionamiento:**
# 1. **Interacción con el Entorno:** Los estudiantes utilizan sus dispositivos móviles (smartphones o tabletas) para escanear su entorno (aula, patio, museo, etc.). La aplicación reconoce diferentes objetos o lugares y superpone información digital relevante sobre ellos.
#
# 2. **Módulos Educativos:** La aplicación incluye varios módulos temáticos:
#    - **Ciencias Naturales:** Al apuntar a un árbol en el patio, los estudiantes pueden ver en 3D las partes del árbol, información sobre su fotosíntesis y su ecosistema. Pueden interactuar con los elementos para aprender más sobre su función.
#    - **Historia:** En un sitio histórico o en el aula, los estudiantes pueden ver reconstrucciones 3D de eventos históricos, personajes o monumentos. Al tocar estos elementos, se despliega información adicional, videos o audios que cuentan la historia detrás de ellos.
#    - **Geografía:** Al escanear un mapa, los estudiantes pueden ver en tiempo real datos sobre diferentes países, como su población, cultura, recursos naturales, etc. También pueden realizar juegos interactivos que les enseñen sobre capitales y banderas.
#    - **Matemáticas:** La aplicación puede proyectar problemas matemáticos en el entorno físico, permitiendo a los estudiantes resolverlos utilizando objetos reales (por ejemplo, contar lápices o medir distancias).
#
# 3. **Retos y Juegos:** Para fomentar el aprendizaje activo, la aplicación incluye retos y juegos donde los estudiantes deben completar tareas relacionadas con los módulos. Por ejemplo, pueden participar en una búsqueda del tesoro donde deben encontrar ciertos elementos en su entorno y responder preguntas relacionadas.
#
# 4. **Colaboración y Competencia:** Los estudiantes pueden trabajar en grupos para completar misiones, fomentando la colaboración. También se pueden organizar competencias entre clases, donde los grupos compiten para completar más retos en un tiempo determinado.
#
# 5. **Seguimiento del Progreso:** La aplicación incluye un sistema de seguimiento que permite a los docentes ver el progreso de cada estudiante, las áreas donde tienen dificultades y los logros alcanzados.
#
# **Beneficios:**
# - **Aprendizaje Activo:** Al interactuar con el contenido, los estudiantes retienen mejor la información.
# - **Motivación Aumentada:** La gamificación y la experiencia inmersiva hacen que aprender sea más atractivo y divertido.
# - **Desarrollo de Habilidades:** Fomenta habilidades como la colaboración, la resolución de problemas y el pensamiento crítico.
#
# **Implementación:**
# La aplicación puede ser utilizada en el aula, en excursiones o en casa como complemento a las tareas. Además, se puede colaborar con instituciones educativas y expertos en cada materia para desarrollar contenido específico y de calidad.
#
# "Exploradores del Conocimiento" no solo transforma la manera en que los estudiantes aprenden, sino que también los motiva a explorar y descubrir el mundo que les rodea de una manera innovadora y emocionante.

# %% [markdown]
# ### Explicación
# - **cadena_secuencial:** permite conectar varias cadenas; la salida de una se convierte en la entrada de la siguiente.
# - En este caso, el modelo primero explica el tema y luego sugiere una aplicación educativa.
#
# Este tipo de flujo es ideal para generar contenido didáctico o ideas para proyectos en clase.

# %% [markdown]
# ## 5️⃣ Ejemplo 3: Añadir memoria a la conversación
# LangChain incluye módulos de **memoria** para mantener contexto entre múltiples interacciones. Esto permite simular conversaciones educativas más naturales, donde el modelo recuerda temas previos.

# %%
# Instalar si hace falta:
# %pip install -U langchain langchain-openai

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.output_parsers import StrOutputParser

# LLM (requiere OPENAI_API_KEY en el entorno)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.5)
to_str = StrOutputParser()

# Prompt con hueco para el historial
prompt = ChatPromptTemplate.from_messages([
    ("system", "Eres un asistente educativo claro y conciso."),
    MessagesPlaceholder("chat_history"),      # ← aquí va la memoria
    ("human", "{input}")
])

# Cadena base
chain = prompt | llm | to_str

# Memoria simple como lista de mensajes
history: list = []

def chat(user_text: str) -> str:
    """
    Envía un turno del usuario, usa el historial y actualiza la memoria
    con el par (usuario, asistente).
    """
    global history
    # Ejecutar la cadena inyectando el historial actual
    answer = chain.invoke({"input": user_text, "chat_history": history})
    # Actualizar memoria (guardar los dos mensajes)
    history += [HumanMessage(content=user_text), AIMessage(content=answer)]
    return answer

# --- Ejemplo de uso (tres turnos) ---
print(chat("Hola, soy un profesor de informática."))
print(chat("¿Puedes explicarme cómo introducir IA a mis estudiantes?"))
print(chat("¿Qué ejemplos prácticos puedo usar en la clase?"))
# Out:
# ¡Hola! Encantado de ayudarte. ¿En qué puedo asistirte hoy en relación con la enseñanza de informática?
# Claro, aquí tienes algunas sugerencias sobre cómo introducir la inteligencia artificial (IA) a tus estudiantes:
#
# 1. **Conceptos Básicos**: Comienza con una introducción a los conceptos fundamentales de la IA, como el aprendizaje automático, el aprendizaje profundo, y la diferencia entre IA débil y fuerte.
#
# 2. **Historia de la IA**: Presenta un breve resumen de la evolución de la IA, desde sus inicios hasta los avances recientes, para contextualizar su importancia.
#
# 3. **Aplicaciones Prácticas**: Muestra ejemplos de aplicaciones de IA en la vida cotidiana, como asistentes virtuales (Siri, Alexa), recomendaciones de productos (Netflix, Amazon) y reconocimiento de imágenes.
#
# 4. **Proyectos Prácticos**: Involucra a los estudiantes en proyectos simples. Por ejemplo, pueden crear un modelo de predicción utilizando herramientas como Scratch o Google Teachable Machine.
#
# 5. **Herramientas y Recursos**: Introduce herramientas accesibles para principiantes, como TensorFlow, Keras o plataformas de IA en línea que no requieren programación.
#
# 6. **Ética en IA**: Discute la importancia de la ética en la IA, incluyendo temas como el sesgo algorítmico y la privacidad de los datos.
#
# 7. **Futuro de la IA**: Anima a los estudiantes a investigar y debatir sobre el futuro de la IA y su impacto en diferentes industrias.
#
# 8. **Invitados Especiales**: Considera invitar a expertos en IA para que compartan sus experiencias y conocimientos con los estudiantes.
#
# Recuerda adaptar el contenido a la edad y nivel de conocimiento de tus estudiantes. ¡Buena suerte!
# Aquí tienes algunos ejemplos prácticos de IA que puedes utilizar en clase:
#
# 1. **Chatbots**: Crea un chatbot simple utilizando plataformas como Chatbot.com o Dialogflow. Los estudiantes pueden aprender sobre procesamiento de lenguaje natural y cómo funcionan las interacciones automatizadas.
#
# 2. **Reconocimiento de Imágenes**: Utiliza herramientas como Google Teachable Machine para que los estudiantes creen un modelo que reconozca imágenes o sonidos. Pueden entrenar el modelo con sus propias fotos o sonidos.
#
# 3. **Predicción de Datos**: Usa conjuntos de datos sencillos (como el conjunto de datos Iris) y herramientas como Google Colab para que los estudiantes realicen análisis de datos y creen modelos de predicción utilizando bibliotecas de Python como Scikit-learn.
#
# 4. **Juegos con IA**: Introduce juegos simples que utilizan IA, como el juego de Tic-Tac-Toe o el de Ahorcado, donde los estudiantes pueden programar la lógica del juego y hacer que la IA compita contra ellos.
#
# 5. **Análisis de Sentimientos**: Utiliza APIs como la de TextBlob o VADER para que los estudiantes analicen textos y determinen el sentimiento (positivo, negativo o neutral) en reseñas de productos o comentarios en redes sociales.
#
# 6. **Reconocimiento de Voz**: Implementa un proyecto sencillo que utilice bibliotecas como SpeechRecognition en Python para que los estudiantes experimenten con el reconocimiento de voz y creen aplicaciones que respondan a comandos de voz.
#
# 7. **Visualización de Datos**: Enseña a los estudiantes a utilizar herramientas de visualización de datos, como Tableau o Power BI, para interpretar datos y mostrar cómo la IA puede ayudar a tomar decisiones basadas en datos.
#
# 8. **Proyectos de Ética**: Organiza debates o proyectos sobre el impacto de la IA en la sociedad, donde los estudiantes investiguen y presenten sobre temas como el sesgo algorítmico o la privacidad.
#
# Estos ejemplos no solo son prácticos, sino que también fomentan la creatividad y el pensamiento crítico en los estudiantes. ¡Espero que te sean útiles!

# %% [markdown]
# ### Explicación
# - **ConversationBufferMemory:** almacena los mensajes anteriores en la conversación.
# - **ConversationChain:** combina el modelo con la memoria.
# - Esta funcionalidad es útil para tutores inteligentes o chatbots educativos que requieren continuidad en el diálogo.

# %% [markdown]
# ## 6️⃣ Buenas prácticas con LangChain + OpenAI
# - Usa prompts **claros y estructurados**: el modelo responde mejor cuando la tarea está bien definida.
# - Controla `temperature` según la tarea: bajo (0.1–0.3) para precisión, alto (0.7–0.9) para creatividad.
# - Guarda logs o historiales si tu aplicación incluye interacción prolongada.
# - Limita la longitud de las respuestas con `max_tokens` para evitar costos o respuestas excesivas.
# - Documenta tus cadenas (`LLMChain`) para reusarlas en distintos contextos educativos.

# %% [markdown]
# ## ✅ Conclusión
# Has aprendido los fundamentos de LangChain: prompts, chains, memoria y flujo secuencial. Estos conceptos son la base para desarrollar asistentes educativos, tutores personalizados o sistemas de generación de contenido en el aula. En la próxima guía implementaremos un **asistente educativo con RAG (Retrieval-Augmented Generation)** usando tus propios materiales docentes.
